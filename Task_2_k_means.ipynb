# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.preprocessing import StandardScaler

# %%
file_path = "/content/Mall_Customers.csv"

# %%
df = pd.read_csv('/content/Mall_Customers.csv')

# %%
print(df.head())
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
features = ["Annual Income (k$)", "Spending Score (1-100)"]

# %%
X = df[features]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df["Cluster"] = kmeans.fit_predict(X_scaled)

# %%
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=df["Cluster"], cmap="viridis", alpha=0.7)

# %%
plt.xlabel("Annual Income (Standardized)")
# Out:
# Text(0.5, 0, 'Annual Income (Standardized)')

# %%
plt.ylabel("Spending Score (Standardized)")
# Out:
# Text(0, 0.5, 'Spending Score (Standardized)')

# %%
plt.title("Customer Segments using K-Means Clustering")
# Out:
# Text(0.5, 1.0, 'Customer Segments using K-Means Clustering')

# %%
plt.show()

# %%
print(df[["CustomerID"] + features + ["Cluster"]])
# Out:
#      CustomerID  Annual Income (k$)  Spending Score (1-100)  Cluster
# 0             1                  15                      39        2
# 1             2                  15                      81        2
# 2             3                  16                       6        2
# 3             4                  16                      77        2
# 4             5                  17                      40        2
# ..          ...                 ...                     ...      ...
# 195         196                 120                      79        1
# 196         197                 126                      28        0
# 197         198                 126                      74        1
# 198         199                 137                      18        0
# 199         200                 137                      83        1
#
# [200 rows x 4 columns]
